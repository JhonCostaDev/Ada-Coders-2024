# %%
import pandas as pd

# %%
listings_path = 'data\\bronze\\listings_bronze.parquet'
listings_silver = pd.read_parquet(listings_path)
listings_silver.sample(10)
# Out:
#                         id                                       listing_url  \
# 12257             51379599             https://www.airbnb.com/rooms/51379599
# 27535  1049449566090581725  https://www.airbnb.com/rooms/1049449566090581725
# 23377   958704251175561796   https://www.airbnb.com/rooms/958704251175561796
# 20030   818814159319707273   https://www.airbnb.com/rooms/818814159319707273
# 5500              16083013             https://www.airbnb.com/rooms/16083013
# 4956              14239230             https://www.airbnb.com/rooms/14239230
# 34091  1174673762341535264  https://www.airbnb.com/rooms/1174673762341535264
# 34118  1172998136079463138  https://www.airbnb.com/rooms/1172998136079463138
# 27594  1050089277302934399  https://www.airbnb.com/rooms/1050089277302934399
# 27217  1044680445761532245  https://www.airbnb.com/rooms/1044680445761532245
#
#             scrape_id last_scraped       source  \
# 12257  20240627045056   2024-06-28  city scrape
# 27535  20240627045056   2024-06-27  city scrape
# 23377  20240627045056   2024-06-28  city scrape
# 20030  20240627045056   2024-06-27  city scrape
# 5500   20240627045056   2024-06-28  city scrape
# 4956   20240627045056   2024-06-27  city scrape
# 34091  20240627045056   2024-06-28  city scrape
# 34118  20240627045056   2024-06-28  city scrape
# 27594  20240627045056   2024-06-28  city scrape
# 27217  20240627045056   2024-06-28  city scrape
#
#                                                     name  \
# 12257               Charmoso aconchegante  Città Vecchia
# 27535  Suíte Tupi Rio Centro  Parque Olímpico Qualistage
# 23377          Apartamento Aconchegante com Verde e Mar.
# 20030       Oásis de tranquilidade no Rio perto do metrô
# 5500                    De frente p/ praia de Copacabana
# 4956               Comfortable, quiet and cozy in Tijuca
# 34091                    Apartamento RJBarra Rock in Rio
# 34118                   Apartamento com Jardim Privativo
# 27594                         Apartamento em Laranjeiras
# 27217                                          Amapola V
#
#                                              description  \
# 12257  Airy apartment clear silent! Old quarter with ...
# 27535  Fully independent suite, with minibar, air con...
# 23377  Airy,  cozy, well-divided, clean and organized...
# 20030  This is a room with a private bathroom in Math...
# 5500   Facing Copacabana beach near supermarkets, res...
# 4956   Located 10 minutes from St. Francis Xavier Met...
# 34091  Safety and tranquility for your family <br />E...
# 34118  Garden Apartment 100% equipped and well decora...
# 27594  A cozy apartment for all!<br />+/- 15 minutes ...
# 27217  Relax with the whole family at this peaceful p...
#
#                                    neighborhood_overview  \
# 12257  Santa Teresa is a hilltop neighborhood with a ...
# 27535  1 km Rio Centro<br />2km Olympic Park.<br />3k...
# 23377  A unique Copacabana place, quiet but close to ...
# 20030  Tijuca is a traditional neighborhood of Rio de...
# 5500   The apartment is in the best place in Copacaba...
# 4956                                                None
# 34091                                               None
# 34118                                               None
# 27594                                               None
# 27217                                               None
#
#                                              picture_url    host_id  ...  \
# 12257  https://a0.muscache.com/pictures/miso/Hosting-...  416092045  ...
# 27535  https://a0.muscache.com/pictures/miso/Hosting-...  511384819  ...
# 23377  https://a0.muscache.com/pictures/ac01f8e5-0400...  498028550  ...
# 20030  https://a0.muscache.com/pictures/miso/Hosting-...  338569184  ...
# 5500   https://a0.muscache.com/pictures/9ee74e41-1cad...  104814492  ...
# 4956   https://a0.muscache.com/pictures/5ed5038b-fd60...   13348213  ...
# 34091  https://a0.muscache.com/pictures/miso/Hosting-...  582291763  ...
# 34118  https://a0.muscache.com/pictures/miso/Hosting-...   64027609  ...
# 27594  https://a0.muscache.com/pictures/hosting/Hosti...  542740841  ...
# 27217  https://a0.muscache.com/pictures/hosting/Hosti...   81548945  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 12257                        4.67                   4.89                4.78
# 27535                        5.00                   5.00                4.67
# 23377                        5.00                   4.83                5.00
# 20030                        5.00                   4.94                5.00
# 5500                         4.98                   4.99                4.87
# 4956                         4.95                   4.95                4.95
# 34091                         NaN                    NaN                 NaN
# 34118                         NaN                    NaN                 NaN
# 27594                        5.00                   5.00                5.00
# 27217                         NaN                    NaN                 NaN
#
#       license instant_bookable calculated_host_listings_count  \
# 12257     NaN                f                              1
# 27535     NaN                f                             18
# 23377     NaN                f                              1
# 20030     NaN                f                              2
# 5500      NaN                f                              1
# 4956      NaN                f                              1
# 34091     NaN                f                              1
# 34118     NaN                f                              1
# 27594     NaN                f                              1
# 27217     NaN                f                              1
#
#       calculated_host_listings_count_entire_homes  \
# 12257                                           1
# 27535                                          15
# 23377                                           1
# 20030                                           1
# 5500                                            1
# 4956                                            0
# 34091                                           1
# 34118                                           1
# 27594                                           1
# 27217                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 12257                                            0
# 27535                                            3
# 23377                                            0
# 20030                                            1
# 5500                                             0
# 4956                                             1
# 34091                                            0
# 34118                                            0
# 27594                                            0
# 27217                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 12257                                           0              0.27
# 27535                                           0              0.51
# 23377                                           0              0.57
# 20030                                           0              3.76
# 5500                                            0              1.13
# 4956                                            0              0.21
# 34091                                           0               NaN
# 34118                                           0               NaN
# 27594                                           0              0.17
# 27217                                           0               NaN
#
# [10 rows x 75 columns]
