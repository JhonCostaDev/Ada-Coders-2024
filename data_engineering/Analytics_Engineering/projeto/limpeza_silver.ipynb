# %%
import pandas as pd

# %%
data_path = 'data\\bronze\\'

# %%
# Carregando os DataFrames
listings_path = data_path + 'listings_bronze.parquet'
calendar_path = data_path + 'calendar_bronze.parquet'
reviews_path = data_path + 'reviews_bronze.parquet'
listings_silver = pd.read_parquet(listings_path)
calendar_silver = pd.read_parquet(calendar_path)
reviews_silver = pd.read_parquet(reviews_path)

# %%
listings_rows, listings_cols = listings_silver.shape
calendar_rows, calendar_cols = calendar_silver.shape
reviews_rows, reviews_cols = reviews_silver.shape
print(
    f'''
Listings: Linhas: {listings_rows}, Colunas {listings_cols}
Calendar: Linhas: {calendar_rows}, Colunas {calendar_cols}
Reviews: Linhas: {reviews_rows}, Colunas {reviews_cols}
    '''
)
# Out:
# Listings: Linhas: 34664, Colunas 75
# Calendar: Linhas: 12652371, Colunas 7
# Reviews: Linhas: 773134, Colunas 6

# %%
listings_silver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34664 entries, 0 to 34663
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            34664 non-null  int64
#  1   listing_url                                   34664 non-null  object
#  2   scrape_id                                     34664 non-null  int64
#  3   last_scraped                                  34664 non-null  object
#  4   source                                        34664 non-null  object
#  5   name                                          34664 non-null  object
#  6   description                                   33501 non-null  object
#  7   neighborhood_overview                         17016 non-null  object
#  8   picture_url                                   34664 non-null  object
# ...

# %%
calendar_silver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12652371 entries, 0 to 12652370
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  float64
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 675.7+ MB

# %%
reviews_silver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 773134 entries, 0 to 773133
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     773134 non-null  int64
#  1   id             773134 non-null  int64
#  2   date           773134 non-null  object
#  3   reviewer_id    773134 non-null  int64
#  4   reviewer_name  773134 non-null  object
#  5   comments       773110 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 35.4+ MB

# %%
listings_silver.sample(10)
# Out:
#                         id                                       listing_url  \
# 21387   864581574158967899   https://www.airbnb.com/rooms/864581574158967899
# 10024             41562792             https://www.airbnb.com/rooms/41562792
# 19781   811631303559623497   https://www.airbnb.com/rooms/811631303559623497
# 22249   910261209419116456   https://www.airbnb.com/rooms/910261209419116456
# 9409              40179166             https://www.airbnb.com/rooms/40179166
# 67                   96478                https://www.airbnb.com/rooms/96478
# 25016  1010276066674304958  https://www.airbnb.com/rooms/1010276066674304958
# 9344              39866230             https://www.airbnb.com/rooms/39866230
# 7457              29286451             https://www.airbnb.com/rooms/29286451
# 30442  1087050586102503833  https://www.airbnb.com/rooms/1087050586102503833
#
#             scrape_id last_scraped       source  \
# 21387  20240627045056   2024-06-27  city scrape
# ...

# %%
calendar_silver.sample(10)
# Out:
#                    listing_id        date available      price  \
# 11989399  1146564055113540362  2025-05-31         f    $169.00
# 6837682    784635761983716388  2025-02-16         f    $360.00
# 4793950              53512617  2025-02-08         t  $1,404.00
# 4780063              53362351  2024-09-04         t    $200.00
# 9901367   1045221225385241773  2024-11-15         t    $650.00
# 979626                8666390  2025-03-23         f    $175.00
# 5930876    695029271419447290  2025-06-06         f    $400.00
# 4672861              53011419  2024-06-30         t  $1,500.00
# 3489825              40428085  2025-05-07         t    $300.00
# 10054000  1049472433654114183  2025-01-28         f    $141.00
#
#           adjusted_price  minimum_nights  maximum_nights
# 11989399             NaN             1.0           365.0
# 6837682              NaN             3.0            15.0
# 4793950              NaN             5.0            90.0
# ...

# %%
reviews_silver.sample(10)
# Out:
#                 listing_id                  id        date  reviewer_id  \
# 107519             3735424           346647772  2018-11-09      1231772
# 394354            38061329           600923217  2020-02-02     83475027
# 407716            39245266  877534704069785384  2023-04-25    137251187
# 93239              2752587  753611187196974829  2022-11-05    164813307
# 489088            47918559  446238003927313151  2021-09-07    295851959
# 22696               658035           339964980  2018-10-22    152185199
# 641710  730370791186458590  822468749814071063  2023-02-08     59947774
# 125846             5077628           539548958  2019-10-01    255782180
# 300164            22423770           346376677  2018-11-08     94681454
# 445851            43425307           637318217  2020-07-12    352941160
#
#           reviewer_name                                           comments
# 107519           George  The flat is very comfortable and in the best l...
# ...

# %%
listings_silver.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
# Tratar nulos e duplicados

# %%
# Tratar Tipagem das colunas

# %%
# Tratar carac

# %%
a = []
a.append([1,2,3,4])

# %%
a
# Out:
# [[1, 2, 3, 4]]

# %%
len(a)
# Out:
# 1

# %%
a = [1]

# %%
a
# Out:
# [1]
