# %% [markdown]
# ##### Wednesday - 9, 2024
# whatsapp ada relacionamento
# (11) 91331-9445
#
#
# Novo Professor: Lucas Ximenes: lxf.lucas@gmail.com

# %% [markdown]
# ![imgem](data_lake.png)
#
#
# ![imgem](api.png)
#
# [Link para banco central](https://olinda.bcb.gov.br/olinda/servico/taxaJuros/versao/v2/documentacao)

# %% [markdown]
# 2. Como Recuperar esses Dados?
#
# API > PYTHON > COLETA > TRATAMENTO > DISPONIBILIZAÇÃO

# %%
# IMPORTAR AS BIBLIOTECAS
import requests
import json 
import pandas as pd

# %%
# URL PARA API (COM FILTRO APENAS DE DATA)
url = "https://olinda.bcb.gov.br/olinda/servico/taxaJuros/versao/v2/odata/TaxasJurosDiariaPorInicioPeriodo?$filter=InicioPeriodo ge '2024-09-01'"

# %%
# REQUISIÇÃO PARA API
response = requests.get(url=url)
print(response)
# Out:
# <Response [200]>

# %%
# TRANSFORMAR RESTPOSTA HTTP EM OBJETO JSON
dados = response.json()
dados
# Out:
# {'@odata.context': 'https://was-p.bcnet.bcb.gov.br/olinda/servico/taxaJuros/versao/v2/odata$metadata#TaxasJurosDiariaPorInicioPeriodo',
#  'value': [{'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 1,
#    'InstituicaoFinanceira': 'BCO MIZUHO S.A.',
#    'TaxaJurosAoMes': 0.08,
#    'TaxaJurosAoAno': 0.97,
#    'cnpj8': '61088183'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 2,
#    'InstituicaoFinanceira': 'BCO SOCIETE GENERALE BRASIL',
#    'TaxaJurosAoMes': 0.08,
#    'TaxaJurosAoAno': 1.0,
#    'cnpj8': '61533584'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 3,
#    'InstituicaoFinanceira': 'BCO CRÉDIT AGRICOLE BR S.A.',
#    'TaxaJurosAoMes': 0.35,
#    'TaxaJurosAoAno': 4.22,
#    'cnpj8': '75647891'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 4,
#    'InstituicaoFinanceira': 'BCO RABOBANK INTL BRASIL S.A.',
#    'TaxaJurosAoMes': 0.45,
#    'TaxaJurosAoAno': 5.54,
#    'cnpj8': '01023570'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 5,
#    'InstituicaoFinanceira': 'BCO DO BRASIL S.A.',
#    'TaxaJurosAoMes': 0.47,
#    'TaxaJurosAoAno': 5.76,
#    'cnpj8': '00000000'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 6,
#    'InstituicaoFinanceira': 'BCO SUMITOMO MITSUI BRASIL S.A.',
#    'TaxaJurosAoMes': 0.48,
#    'TaxaJurosAoAno': 5.86,
#    'cnpj8': '60518222'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 7,
#    'InstituicaoFinanceira': 'BCO CITIBANK S.A.',
#    'TaxaJurosAoMes': 0.48,
#    'TaxaJurosAoAno': 5.94,
#    'cnpj8': '33479023'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 8,
#    'InstituicaoFinanceira': 'BCO HSBC S.A.',
#    'TaxaJurosAoMes': 0.49,
#    'TaxaJurosAoAno': 5.98,
#    'cnpj8': '53518684'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 9,
#    'InstituicaoFinanceira': 'BCO CAIXA GERAL BRASIL S.A.',
#    'TaxaJurosAoMes': 0.52,
#    'TaxaJurosAoAno': 6.45,
#    'cnpj8': '33466988'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 10,
#    'InstituicaoFinanceira': 'BCO BRADESCO S.A.',
#    'TaxaJurosAoMes': 0.53,
#    'TaxaJurosAoAno': 6.6,
#    'cnpj8': '60746948'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 11,
#    'InstituicaoFinanceira': 'BCO ABC BRASIL S.A.',
#    'TaxaJurosAoMes': 0.56,
#    'TaxaJurosAoAno': 6.9,
#    'cnpj8': '28195667'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 12,
#    'InstituicaoFinanceira': 'BCO SANTANDER (BRASIL) S.A.',
#    'TaxaJurosAoMes': 0.56,
#    'TaxaJurosAoAno': 6.92,
#    'cnpj8': '90400888'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 13,
#    'InstituicaoFinanceira': 'BCO DO NORDESTE DO BRASIL S.A.',
#    'TaxaJurosAoMes': 0.62,
#    'TaxaJurosAoAno': 7.69,
#    'cnpj8': '07237373'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 14,
#    'InstituicaoFinanceira': 'BCO COOPERATIVO SICREDI S.A.',
#    'TaxaJurosAoMes': 0.62,
#    'TaxaJurosAoAno': 7.69,
#    'cnpj8': '01181521'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 15,
#    'InstituicaoFinanceira': 'CAIXA ECONOMICA FEDERAL',
#    'TaxaJurosAoMes': 0.63,
#    'TaxaJurosAoAno': 7.88,
#    'cnpj8': '00360305'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 16,
#    'InstituicaoFinanceira': 'BCO VOTORANTIM S.A.',
#    'TaxaJurosAoMes': 0.64,
#    'TaxaJurosAoAno': 8.01,
#    'cnpj8': '59588111'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 17,
#    'InstituicaoFinanceira': 'BCO SAFRA S.A.',
#    'TaxaJurosAoMes': 0.66,
#    'TaxaJurosAoAno': 8.16,
#    'cnpj8': '58160789'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 18,
#    'InstituicaoFinanceira': 'BCO DO ESTADO DO RS S.A.',
#    'TaxaJurosAoMes': 0.67,
#    'TaxaJurosAoAno': 8.3,
#    'cnpj8': '92702067'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 19,
#    'InstituicaoFinanceira': 'ITAÚ UNIBANCO S.A.',
#    'TaxaJurosAoMes': 0.68,
#    'TaxaJurosAoAno': 8.51,
#    'cnpj8': '60701190'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 20,
#    'InstituicaoFinanceira': 'BCO C6 S.A.',
#    'TaxaJurosAoMes': 0.71,
#    'TaxaJurosAoAno': 8.81,
#    'cnpj8': '31872495'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 21,
#    'InstituicaoFinanceira': 'BCO INDUSTRIAL DO BRASIL S.A.',
#    'TaxaJurosAoMes': 0.71,
#    'TaxaJurosAoAno': 8.82,
#    'cnpj8': '31895683'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 22,
#    'InstituicaoFinanceira': 'BCO DA CHINA BRASIL S.A.',
#    'TaxaJurosAoMes': 0.71,
#    'TaxaJurosAoAno': 8.92,
#    'cnpj8': '10690848'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 23,
#    'InstituicaoFinanceira': 'BCO SOFISA S.A.',
#    'TaxaJurosAoMes': 0.74,
#    'TaxaJurosAoAno': 9.19,
#    'cnpj8': '60889128'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 24,
#    'InstituicaoFinanceira': 'BCO DAYCOVAL S.A',
#    'TaxaJurosAoMes': 0.75,
#    'TaxaJurosAoAno': 9.33,
#    'cnpj8': '62232889'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 25,
#    'InstituicaoFinanceira': 'BANCO SICOOB S.A.',
#    'TaxaJurosAoMes': 0.77,
#    'TaxaJurosAoAno': 9.61,
#    'cnpj8': '02038232'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 26,
#    'InstituicaoFinanceira': 'BCO BS2 S.A.',
#    'TaxaJurosAoMes': 0.8,
#    'TaxaJurosAoAno': 10.02,
#    'cnpj8': '71027866'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 27,
#    'InstituicaoFinanceira': 'BANCO INTER',
#    'TaxaJurosAoMes': 0.83,
#    'TaxaJurosAoAno': 10.4,
#    'cnpj8': '00416968'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 28,
#    'InstituicaoFinanceira': 'TRAVELEX BANCO DE CÂMBIO S.A.',
#    'TaxaJurosAoMes': 1.17,
#    'TaxaJurosAoAno': 15.0,
#    'cnpj8': '11703662'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 29,
#    'InstituicaoFinanceira': 'BANCO VOITER',
#    'TaxaJurosAoMes': 1.19,
#    'TaxaJurosAoAno': 15.2,
#    'cnpj8': '61024352'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Adiantamento sobre contratos de câmbio (ACC) - Pós-fixado referenciado em moeda estrangeira',
#    'Posicao': 30,
#    'InstituicaoFinanceira': 'NOVO BCO CONTINENTAL S.A. - BM',
#    'TaxaJurosAoMes': 4.42,
#    'TaxaJurosAoAno': 67.98,
#    'cnpj8': '74828799'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 1,
#    'InstituicaoFinanceira': 'BCO BS2 S.A.',
#    'TaxaJurosAoMes': 0.87,
#    'TaxaJurosAoAno': 10.98,
#    'cnpj8': '71027866'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 2,
#    'InstituicaoFinanceira': 'BCO VOTORANTIM S.A.',
#    'TaxaJurosAoMes': 0.9,
#    'TaxaJurosAoAno': 11.31,
#    'cnpj8': '59588111'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 3,
#    'InstituicaoFinanceira': 'ITAÚ UNIBANCO S.A.',
#    'TaxaJurosAoMes': 0.91,
#    'TaxaJurosAoAno': 11.47,
#    'cnpj8': '60701190'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 4,
#    'InstituicaoFinanceira': 'BCO SAFRA S.A.',
#    'TaxaJurosAoMes': 0.91,
#    'TaxaJurosAoAno': 11.51,
#    'cnpj8': '58160789'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 5,
#    'InstituicaoFinanceira': 'NU FINANCEIRA S.A. CFI',
#    'TaxaJurosAoMes': 0.92,
#    'TaxaJurosAoAno': 11.61,
#    'cnpj8': '30680829'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 6,
#    'InstituicaoFinanceira': 'BCO FIBRA S.A.',
#    'TaxaJurosAoMes': 0.92,
#    'TaxaJurosAoAno': 11.64,
#    'cnpj8': '58616418'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 7,
#    'InstituicaoFinanceira': 'BCO BRADESCO S.A.',
#    'TaxaJurosAoMes': 0.94,
#    'TaxaJurosAoAno': 11.82,
#    'cnpj8': '60746948'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 8,
#    'InstituicaoFinanceira': 'BANCO BTG PACTUAL S.A.',
#    'TaxaJurosAoMes': 0.95,
#    'TaxaJurosAoAno': 11.95,
#    'cnpj8': '30306294'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 9,
#    'InstituicaoFinanceira': 'BCO DO BRASIL S.A.',
#    'TaxaJurosAoMes': 0.98,
#    'TaxaJurosAoAno': 12.38,
#    'cnpj8': '00000000'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 10,
#    'InstituicaoFinanceira': 'BCO HSBC S.A.',
#    'TaxaJurosAoMes': 1.0,
#    'TaxaJurosAoAno': 12.66,
#    'cnpj8': '53518684'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 11,
#    'InstituicaoFinanceira': 'BCO XP S.A.',
#    'TaxaJurosAoMes': 1.15,
#    'TaxaJurosAoAno': 14.71,
#    'cnpj8': '33264668'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 12,
#    'InstituicaoFinanceira': 'BCO C6 S.A.',
#    'TaxaJurosAoMes': 1.17,
#    'TaxaJurosAoAno': 14.94,
#    'cnpj8': '31872495'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 13,
#    'InstituicaoFinanceira': 'BCO SANTANDER (BRASIL) S.A.',
#    'TaxaJurosAoMes': 1.24,
#    'TaxaJurosAoAno': 15.92,
#    'cnpj8': '90400888'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 14,
#    'InstituicaoFinanceira': 'BCO SENFF S.A.',
#    'TaxaJurosAoMes': 1.64,
#    'TaxaJurosAoAno': 21.48,
#    'cnpj8': '11970623'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 15,
#    'InstituicaoFinanceira': 'BCO DA AMAZONIA S.A.',
#    'TaxaJurosAoMes': 1.78,
#    'TaxaJurosAoAno': 23.54,
#    'cnpj8': '04902979'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Antecipação de faturas de cartão de crédito - Pré-fixado',
#    'Posicao': 16,
#    'InstituicaoFinanceira': 'BCO RIBEIRAO PRETO S.A.',
#    'TaxaJurosAoMes': 1.98,
#    'TaxaJurosAoAno': 26.45,
#    'cnpj8': '00517645'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 1,
#    'InstituicaoFinanceira': 'SINOSSERRA S/A - SCFI',
#    'TaxaJurosAoMes': 0.33,
#    'TaxaJurosAoAno': 4.0,
#    'cnpj8': '22639377'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 2,
#    'InstituicaoFinanceira': 'DEUTSCHE SPARKASSEN LEASING DO BRASIL BM S.A.',
#    'TaxaJurosAoMes': 0.78,
#    'TaxaJurosAoAno': 9.71,
#    'cnpj8': '23511655'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 3,
#    'InstituicaoFinanceira': 'BCO DE LAGE LANDEN BRASIL S.A.',
#    'TaxaJurosAoMes': 0.82,
#    'TaxaJurosAoAno': 10.25,
#    'cnpj8': '05040481'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 4,
#    'InstituicaoFinanceira': 'BCO CATERPILLAR S.A.',
#    'TaxaJurosAoMes': 1.16,
#    'TaxaJurosAoAno': 14.8,
#    'cnpj8': '02658435'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 5,
#    'InstituicaoFinanceira': 'BANCO SICOOB S.A.',
#    'TaxaJurosAoMes': 1.31,
#    'TaxaJurosAoAno': 16.84,
#    'cnpj8': '02038232'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 6,
#    'InstituicaoFinanceira': 'BANCO CNH INDUSTRIAL CAPITAL S.A',
#    'TaxaJurosAoMes': 1.41,
#    'TaxaJurosAoAno': 18.25,
#    'cnpj8': '02992446'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 7,
#    'InstituicaoFinanceira': 'BCO DO EST. DO PA S.A.',
#    'TaxaJurosAoMes': 1.54,
#    'TaxaJurosAoAno': 20.08,
#    'cnpj8': '04913711'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 8,
#    'InstituicaoFinanceira': 'BCO VOLKSWAGEN S.A',
#    'TaxaJurosAoMes': 1.66,
#    'TaxaJurosAoAno': 21.85,
#    'cnpj8': '59109165'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 9,
#    'InstituicaoFinanceira': 'BCO BANESTES S.A.',
#    'TaxaJurosAoMes': 1.7,
#    'TaxaJurosAoAno': 22.41,
#    'cnpj8': '28127603'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 10,
#    'InstituicaoFinanceira': 'BCO BRADESCO S.A.',
#    'TaxaJurosAoMes': 1.73,
#    'TaxaJurosAoAno': 22.82,
#    'cnpj8': '60746948'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 11,
#    'InstituicaoFinanceira': 'TODESCREDI S/A - CFI',
#    'TaxaJurosAoMes': 1.94,
#    'TaxaJurosAoAno': 25.95,
#    'cnpj8': '09473806'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 12,
#    'InstituicaoFinanceira': 'AYMORÉ CFI S.A.',
#    'TaxaJurosAoMes': 1.94,
#    'TaxaJurosAoAno': 25.99,
#    'cnpj8': '07707650'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 13,
#    'InstituicaoFinanceira': 'BCO SANTANDER (BRASIL) S.A.',
#    'TaxaJurosAoMes': 2.0,
#    'TaxaJurosAoAno': 26.77,
#    'cnpj8': '90400888'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 14,
#    'InstituicaoFinanceira': 'BCO DO ESTADO DO RS S.A.',
#    'TaxaJurosAoMes': 2.07,
#    'TaxaJurosAoAno': 27.81,
#    'cnpj8': '92702067'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 15,
#    'InstituicaoFinanceira': 'BCO VOTORANTIM S.A.',
#    'TaxaJurosAoMes': 2.16,
#    'TaxaJurosAoAno': 29.26,
#    'cnpj8': '59588111'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 16,
#    'InstituicaoFinanceira': 'BCO DO BRASIL S.A.',
#    'TaxaJurosAoMes': 2.27,
#    'TaxaJurosAoAno': 30.89,
#    'cnpj8': '00000000'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 17,
#    'InstituicaoFinanceira': 'BCO BRADESCO FINANC. S.A.',
#    'TaxaJurosAoMes': 2.63,
#    'TaxaJurosAoAno': 36.6,
#    'cnpj8': '07207996'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 18,
#    'InstituicaoFinanceira': 'BCO VOLVO BRASIL S.A.',
#    'TaxaJurosAoMes': 2.66,
#    'TaxaJurosAoAno': 36.96,
#    'cnpj8': '58017179'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 19,
#    'InstituicaoFinanceira': 'BCO SENFF S.A.',
#    'TaxaJurosAoMes': 2.86,
#    'TaxaJurosAoAno': 40.33,
#    'cnpj8': '11970623'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 20,
#    'InstituicaoFinanceira': 'BCO RENDIMENTO S.A.',
#    'TaxaJurosAoMes': 3.67,
#    'TaxaJurosAoAno': 54.05,
#    'cnpj8': '68900810'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 21,
#    'InstituicaoFinanceira': 'LEBES FINANCEIRA CFI SA',
#    'TaxaJurosAoMes': 3.81,
#    'TaxaJurosAoAno': 56.59,
#    'cnpj8': '11271860'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 22,
#    'InstituicaoFinanceira': 'HS FINANCEIRA',
#    'TaxaJurosAoMes': 3.82,
#    'TaxaJurosAoAno': 56.73,
#    'cnpj8': '07512441'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 23,
#    'InstituicaoFinanceira': 'BECKER FINANCEIRA SA - CFI',
#    'TaxaJurosAoMes': 4.09,
#    'TaxaJurosAoAno': 61.72,
#    'cnpj8': '20443996'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 24,
#    'InstituicaoFinanceira': 'KREDILIG S.A. - CFI',
#    'TaxaJurosAoMes': 4.5,
#    'TaxaJurosAoAno': 69.59,
#    'cnpj8': '06040559'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 25,
#    'InstituicaoFinanceira': 'CENTROCRED S.A. CFI',
#    'TaxaJurosAoMes': 4.73,
#    'TaxaJurosAoAno': 74.04,
#    'cnpj8': '26225776'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 26,
#    'InstituicaoFinanceira': 'CREDIARE CFI S.A.',
#    'TaxaJurosAoMes': 5.0,
#    'TaxaJurosAoAno': 79.62,
#    'cnpj8': '05676026'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 27,
#    'InstituicaoFinanceira': 'BANCO INTER',
#    'TaxaJurosAoMes': 5.83,
#    'TaxaJurosAoAno': 97.4,
#    'cnpj8': '00416968'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 28,
#    'InstituicaoFinanceira': 'VIA CERTA FINANCIADORA S.A. - CFI',
#    'TaxaJurosAoMes': 5.87,
#    'TaxaJurosAoAno': 98.23,
#    'cnpj8': '05192316'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 29,
#    'InstituicaoFinanceira': 'GRAZZIOTIN FINANCEIRA S/A',
#    'TaxaJurosAoMes': 6.21,
#    'TaxaJurosAoAno': 106.16,
#    'cnpj8': '06339468'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 30,
#    'InstituicaoFinanceira': 'NEGRESCO S.A. - CFI',
#    'TaxaJurosAoMes': 6.87,
#    'TaxaJurosAoAno': 121.89,
#    'cnpj8': '04379829'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 31,
#    'InstituicaoFinanceira': 'MERCADO CRÉDITO SCFI S.A.',
#    'TaxaJurosAoMes': 6.96,
#    'TaxaJurosAoAno': 124.09,
#    'cnpj8': '37679449'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 32,
#    'InstituicaoFinanceira': 'GAZINCRED S.A. SCFI',
#    'TaxaJurosAoMes': 7.15,
#    'TaxaJurosAoAno': 128.92,
#    'cnpj8': '11760553'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 33,
#    'InstituicaoFinanceira': 'BANCO SEMEAR',
#    'TaxaJurosAoMes': 7.23,
#    'TaxaJurosAoAno': 131.01,
#    'cnpj8': '00795423'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 34,
#    'InstituicaoFinanceira': 'ZEMA CFI S/A',
#    'TaxaJurosAoMes': 7.34,
#    'TaxaJurosAoAno': 134.0,
#    'cnpj8': '05351887'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de outros bens - Pré-fixado',
#    'Posicao': 35,
#    'InstituicaoFinanceira': 'AGORACRED S/A SCFI',
#    'TaxaJurosAoMes': 7.48,
#    'TaxaJurosAoAno': 137.65,
#    'cnpj8': '36321990'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 1,
#    'InstituicaoFinanceira': 'BMW FINANCEIRA S.A. - CFI',
#    'TaxaJurosAoMes': 0.63,
#    'TaxaJurosAoAno': 7.8,
#    'cnpj8': '04452473'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 2,
#    'InstituicaoFinanceira': 'BCO MERCEDES-BENZ S.A.',
#    'TaxaJurosAoMes': 0.77,
#    'TaxaJurosAoAno': 9.7,
#    'cnpj8': '60814191'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 3,
#    'InstituicaoFinanceira': 'BCO GM S.A.',
#    'TaxaJurosAoMes': 0.96,
#    'TaxaJurosAoAno': 12.09,
#    'cnpj8': '59274605'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 4,
#    'InstituicaoFinanceira': 'STELLANTIS FINANCIAMENTOS CFI',
#    'TaxaJurosAoMes': 1.07,
#    'TaxaJurosAoAno': 13.61,
#    'cnpj8': '03502961'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 5,
#    'InstituicaoFinanceira': 'BCO DA AMAZONIA S.A.',
#    'TaxaJurosAoMes': 1.1,
#    'TaxaJurosAoAno': 13.96,
#    'cnpj8': '04902979'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 6,
#    'InstituicaoFinanceira': 'BANCO CNH INDUSTRIAL CAPITAL S.A',
#    'TaxaJurosAoMes': 1.11,
#    'TaxaJurosAoAno': 14.2,
#    'cnpj8': '02992446'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 7,
#    'InstituicaoFinanceira': 'BCO RCI BRASIL S.A.',
#    'TaxaJurosAoMes': 1.16,
#    'TaxaJurosAoAno': 14.79,
#    'cnpj8': '62307848'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 8,
#    'InstituicaoFinanceira': 'SCANIA BCO S.A.',
#    'TaxaJurosAoMes': 1.18,
#    'TaxaJurosAoAno': 15.11,
#    'cnpj8': '11417016'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 9,
#    'InstituicaoFinanceira': 'BCO VOLVO BRASIL S.A.',
#    'TaxaJurosAoMes': 1.22,
#    'TaxaJurosAoAno': 15.6,
#    'cnpj8': '58017179'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 10,
#    'InstituicaoFinanceira': 'BANCO HYUNDAI CAPITAL BRASIL',
#    'TaxaJurosAoMes': 1.27,
#    'TaxaJurosAoAno': 16.28,
#    'cnpj8': '30172491'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 11,
#    'InstituicaoFinanceira': 'BCO PACCAR S.A.',
#    'TaxaJurosAoMes': 1.27,
#    'TaxaJurosAoAno': 16.34,
#    'cnpj8': '28517628'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 12,
#    'InstituicaoFinanceira': 'BCO VOLKSWAGEN S.A',
#    'TaxaJurosAoMes': 1.29,
#    'TaxaJurosAoAno': 16.69,
#    'cnpj8': '59109165'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 13,
#    'InstituicaoFinanceira': 'BANCO INTER',
#    'TaxaJurosAoMes': 1.37,
#    'TaxaJurosAoAno': 17.77,
#    'cnpj8': '00416968'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 14,
#    'InstituicaoFinanceira': 'BRB - CFI S/A',
#    'TaxaJurosAoMes': 1.5,
#    'TaxaJurosAoAno': 19.62,
#    'cnpj8': '33136888'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 15,
#    'InstituicaoFinanceira': 'BCO RODOBENS S.A.',
#    'TaxaJurosAoMes': 1.54,
#    'TaxaJurosAoAno': 20.13,
#    'cnpj8': '33603457'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 16,
#    'InstituicaoFinanceira': 'BCO BRADESCO S.A.',
#    'TaxaJurosAoMes': 1.57,
#    'TaxaJurosAoAno': 20.5,
#    'cnpj8': '60746948'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 17,
#    'InstituicaoFinanceira': 'BANCO MONEO S.A.',
#    'TaxaJurosAoMes': 1.57,
#    'TaxaJurosAoAno': 20.55,
#    'cnpj8': '07441209'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 18,
#    'InstituicaoFinanceira': 'BCO SAFRA S.A.',
#    'TaxaJurosAoMes': 1.58,
#    'TaxaJurosAoAno': 20.74,
#    'cnpj8': '58160789'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 19,
#    'InstituicaoFinanceira': 'BCO. J.SAFRA S.A.',
#    'TaxaJurosAoMes': 1.6,
#    'TaxaJurosAoAno': 21.0,
#    'cnpj8': '03017677'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 20,
#    'InstituicaoFinanceira': 'BCO TOYOTA DO BRASIL S.A.',
#    'TaxaJurosAoMes': 1.66,
#    'TaxaJurosAoAno': 21.87,
#    'cnpj8': '03215790'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 21,
#    'InstituicaoFinanceira': 'FINANC ALFA S.A. CFI',
#    'TaxaJurosAoMes': 1.68,
#    'TaxaJurosAoAno': 22.09,
#    'cnpj8': '17167412'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 22,
#    'InstituicaoFinanceira': 'BCO BRASILEIRO DE CRÉDITO S.A.',
#    'TaxaJurosAoMes': 1.69,
#    'TaxaJurosAoAno': 22.21,
#    'cnpj8': '01852137'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 23,
#    'InstituicaoFinanceira': 'CAIXA ECONOMICA FEDERAL',
#    'TaxaJurosAoMes': 1.71,
#    'TaxaJurosAoAno': 22.58,
#    'cnpj8': '00360305'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 24,
#    'InstituicaoFinanceira': 'SAFRA CFI S.A.',
#    'TaxaJurosAoMes': 1.73,
#    'TaxaJurosAoAno': 22.8,
#    'cnpj8': '45437547'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 25,
#    'InstituicaoFinanceira': 'BCO BANESTES S.A.',
#    'TaxaJurosAoMes': 1.74,
#    'TaxaJurosAoAno': 22.99,
#    'cnpj8': '28127603'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 26,
#    'InstituicaoFinanceira': 'BCO DO BRASIL S.A.',
#    'TaxaJurosAoMes': 1.79,
#    'TaxaJurosAoAno': 23.73,
#    'cnpj8': '00000000'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 27,
#    'InstituicaoFinanceira': 'BCO SANTANDER (BRASIL) S.A.',
#    'TaxaJurosAoMes': 1.79,
#    'TaxaJurosAoAno': 23.75,
#    'cnpj8': '90400888'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 28,
#    'InstituicaoFinanceira': 'PORTOSEG S.A. CFI',
#    'TaxaJurosAoMes': 1.82,
#    'TaxaJurosAoAno': 24.2,
#    'cnpj8': '04862600'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 29,
#    'InstituicaoFinanceira': 'BCO C6 S.A.',
#    'TaxaJurosAoMes': 1.87,
#    'TaxaJurosAoAno': 24.86,
#    'cnpj8': '31872495'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 30,
#    'InstituicaoFinanceira': 'AYMORÉ CFI S.A.',
#    'TaxaJurosAoMes': 1.91,
#    'TaxaJurosAoAno': 25.44,
#    'cnpj8': '07707650'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 31,
#    'InstituicaoFinanceira': 'BCO BRADESCO FINANC. S.A.',
#    'TaxaJurosAoMes': 1.91,
#    'TaxaJurosAoAno': 25.49,
#    'cnpj8': '07207996'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 32,
#    'InstituicaoFinanceira': 'ITAÚ UNIBANCO HOLDING S.A.',
#    'TaxaJurosAoMes': 1.92,
#    'TaxaJurosAoAno': 25.56,
#    'cnpj8': '60872504'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 33,
#    'InstituicaoFinanceira': 'SINOSSERRA S/A - SCFI',
#    'TaxaJurosAoMes': 1.96,
#    'TaxaJurosAoAno': 26.24,
#    'cnpj8': '22639377'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 34,
#    'InstituicaoFinanceira': 'BANCO BTG PACTUAL S.A.',
#    'TaxaJurosAoMes': 1.98,
#    'TaxaJurosAoAno': 26.51,
#    'cnpj8': '30306294'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 35,
#    'InstituicaoFinanceira': 'BCO VOTORANTIM S.A.',
#    'TaxaJurosAoMes': 2.14,
#    'TaxaJurosAoAno': 28.9,
#    'cnpj8': '59588111'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 36,
#    'InstituicaoFinanceira': 'BCO HONDA S.A.',
#    'TaxaJurosAoMes': 2.17,
#    'TaxaJurosAoAno': 29.35,
#    'cnpj8': '03634220'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 37,
#    'InstituicaoFinanceira': 'BCO DO ESTADO DO RS S.A.',
#    'TaxaJurosAoMes': 2.43,
#    'TaxaJurosAoAno': 33.4,
#    'cnpj8': '92702067'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 38,
#    'InstituicaoFinanceira': 'BCO YAMAHA MOTOR S.A.',
#    'TaxaJurosAoMes': 2.5,
#    'TaxaJurosAoAno': 34.48,
#    'cnpj8': '10371492'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 39,
#    'InstituicaoFinanceira': 'BCO DIGIMAIS S.A.',
#    'TaxaJurosAoMes': 2.59,
#    'TaxaJurosAoAno': 35.96,
#    'cnpj8': '92874270'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 40,
#    'InstituicaoFinanceira': 'SIMPALA S.A. CFI',
#    'TaxaJurosAoMes': 2.89,
#    'TaxaJurosAoAno': 40.74,
#    'cnpj8': '34991938'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 41,
#    'InstituicaoFinanceira': 'FINAMAX S.A. CFI',
#    'TaxaJurosAoMes': 2.92,
#    'TaxaJurosAoAno': 41.29,
#    'cnpj8': '00411939'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 42,
#    'InstituicaoFinanceira': 'BCO DAYCOVAL S.A',
#    'TaxaJurosAoMes': 2.99,
#    'TaxaJurosAoAno': 42.39,
#    'cnpj8': '62232889'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 43,
#    'InstituicaoFinanceira': 'BANCO PAN',
#    'TaxaJurosAoMes': 3.01,
#    'TaxaJurosAoAno': 42.67,
#    'cnpj8': '59285411'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA FÍSICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Aquisição de veículos - Pré-fixado',
#    'Posicao': 44,
#    'InstituicaoFinanceira': 'OMNI SA CFI',
#    'TaxaJurosAoMes': 3.29,
#    'TaxaJurosAoAno': 47.54,
#    'cnpj8': '92228410'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 1,
#    'InstituicaoFinanceira': 'BCO VOLKSWAGEN S.A',
#    'TaxaJurosAoMes': 0.1,
#    'TaxaJurosAoAno': 1.18,
#    'cnpj8': '59109165'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 2,
#    'InstituicaoFinanceira': 'BCO DES. DE MG S.A.',
#    'TaxaJurosAoMes': 0.23,
#    'TaxaJurosAoAno': 2.83,
#    'cnpj8': '38486817'},
#   {'InicioPeriodo': '2024-09-20',
#    'FimPeriodo': '2024-09-26',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
# ...
#    'TaxaJurosAoMes': 1.5,
#    'TaxaJurosAoAno': 19.54,
#    'cnpj8': '92894922'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 10,
#    'InstituicaoFinanceira': 'BANCO INBURSA',
#    'TaxaJurosAoMes': 1.62,
#    'TaxaJurosAoAno': 21.23,
#    'cnpj8': '04866275'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 11,
#    'InstituicaoFinanceira': 'BCO DO NORDESTE DO BRASIL S.A.',
#    'TaxaJurosAoMes': 1.65,
#    'TaxaJurosAoAno': 21.65,
#    'cnpj8': '07237373'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 12,
#    'InstituicaoFinanceira': 'BCO SOFISA S.A.',
#    'TaxaJurosAoMes': 1.67,
#    'TaxaJurosAoAno': 21.97,
#    'cnpj8': '60889128'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 13,
#    'InstituicaoFinanceira': 'BCO LA PROVINCIA B AIRES BCE',
#    'TaxaJurosAoMes': 1.69,
#    'TaxaJurosAoAno': 22.21,
#    'cnpj8': '44189447'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 14,
#    'InstituicaoFinanceira': 'BCO DAYCOVAL S.A',
#    'TaxaJurosAoMes': 1.72,
#    'TaxaJurosAoAno': 22.69,
#    'cnpj8': '62232889'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 15,
#    'InstituicaoFinanceira': 'SCANIA BCO S.A.',
#    'TaxaJurosAoMes': 1.84,
#    'TaxaJurosAoAno': 24.4,
#    'cnpj8': '11417016'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 16,
#    'InstituicaoFinanceira': 'BCO BS2 S.A.',
#    'TaxaJurosAoMes': 1.87,
#    'TaxaJurosAoAno': 24.94,
#    'cnpj8': '71027866'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 17,
#    'InstituicaoFinanceira': 'BCO SAFRA S.A.',
#    'TaxaJurosAoMes': 1.89,
#    'TaxaJurosAoAno': 25.26,
#    'cnpj8': '58160789'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 18,
#    'InstituicaoFinanceira': 'ITAÚ UNIBANCO S.A.',
#    'TaxaJurosAoMes': 1.92,
#    'TaxaJurosAoAno': 25.64,
#    'cnpj8': '60701190'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 19,
#    'InstituicaoFinanceira': 'BCO BRADESCO S.A.',
#    'TaxaJurosAoMes': 1.99,
#    'TaxaJurosAoAno': 26.64,
#    'cnpj8': '60746948'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 20,
#    'InstituicaoFinanceira': 'BCO GUANABARA S.A.',
#    'TaxaJurosAoMes': 2.04,
#    'TaxaJurosAoAno': 27.36,
#    'cnpj8': '31880826'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 21,
#    'InstituicaoFinanceira': 'BANCO SEMEAR',
#    'TaxaJurosAoMes': 2.04,
#    'TaxaJurosAoAno': 27.41,
#    'cnpj8': '00795423'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 22,
#    'InstituicaoFinanceira': 'BCO HONDA S.A.',
#    'TaxaJurosAoMes': 2.12,
#    'TaxaJurosAoAno': 28.68,
#    'cnpj8': '03634220'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 23,
#    'InstituicaoFinanceira': 'BCO VOLVO BRASIL S.A.',
#    'TaxaJurosAoMes': 2.17,
#    'TaxaJurosAoAno': 29.43,
#    'cnpj8': '58017179'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 24,
#    'InstituicaoFinanceira': 'QISTA S.A. CFI',
#    'TaxaJurosAoMes': 2.22,
#    'TaxaJurosAoAno': 30.16,
#    'cnpj8': '36583700'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 25,
#    'InstituicaoFinanceira': 'BCO DA AMAZONIA S.A.',
#    'TaxaJurosAoMes': 2.41,
#    'TaxaJurosAoAno': 33.03,
#    'cnpj8': '04902979'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 26,
#    'InstituicaoFinanceira': 'BCO DO EST. DO PA S.A.',
#    'TaxaJurosAoMes': 2.45,
#    'TaxaJurosAoAno': 33.7,
#    'cnpj8': '04913711'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 27,
#    'InstituicaoFinanceira': 'BANCO BARI S.A.',
#    'TaxaJurosAoMes': 2.47,
#    'TaxaJurosAoAno': 33.97,
#    'cnpj8': '00556603'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 28,
#    'InstituicaoFinanceira': 'BANCO TOPÁZIO S.A.',
#    'TaxaJurosAoMes': 2.51,
#    'TaxaJurosAoAno': 34.63,
#    'cnpj8': '07679404'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 29,
#    'InstituicaoFinanceira': 'LECCA CFI S.A.',
#    'TaxaJurosAoMes': 2.52,
#    'TaxaJurosAoAno': 34.82,
#    'cnpj8': '07652226'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 30,
#    'InstituicaoFinanceira': 'BCO INDUSTRIAL DO BRASIL S.A.',
#    'TaxaJurosAoMes': 2.56,
#    'TaxaJurosAoAno': 35.46,
#    'cnpj8': '31895683'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 31,
#    'InstituicaoFinanceira': 'BCO DO ESTADO DO RS S.A.',
#    'TaxaJurosAoMes': 2.59,
#    'TaxaJurosAoAno': 35.89,
#    'cnpj8': '92702067'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 32,
#    'InstituicaoFinanceira': 'BCO ARBI S.A.',
#    'TaxaJurosAoMes': 2.6,
#    'TaxaJurosAoAno': 36.05,
#    'cnpj8': '54403563'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 33,
#    'InstituicaoFinanceira': 'BCO DO BRASIL S.A.',
#    'TaxaJurosAoMes': 2.61,
#    'TaxaJurosAoAno': 36.31,
#    'cnpj8': '00000000'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 34,
#    'InstituicaoFinanceira': 'BCO SANTANDER (BRASIL) S.A.',
#    'TaxaJurosAoMes': 2.69,
#    'TaxaJurosAoAno': 37.51,
#    'cnpj8': '90400888'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 35,
#    'InstituicaoFinanceira': 'BCO SENFF S.A.',
#    'TaxaJurosAoMes': 3.07,
#    'TaxaJurosAoAno': 43.74,
#    'cnpj8': '11970623'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 36,
#    'InstituicaoFinanceira': 'BCO RENDIMENTO S.A.',
#    'TaxaJurosAoMes': 3.08,
#    'TaxaJurosAoAno': 43.95,
#    'cnpj8': '68900810'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 37,
#    'InstituicaoFinanceira': 'PORTOSEG S.A. CFI',
#    'TaxaJurosAoMes': 3.13,
#    'TaxaJurosAoAno': 44.8,
#    'cnpj8': '04862600'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 38,
#    'InstituicaoFinanceira': 'BCO BANESTES S.A.',
#    'TaxaJurosAoMes': 3.21,
#    'TaxaJurosAoAno': 46.12,
#    'cnpj8': '28127603'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 39,
#    'InstituicaoFinanceira': 'BCO TRIANGULO S.A.',
#    'TaxaJurosAoMes': 3.27,
#    'TaxaJurosAoAno': 47.15,
#    'cnpj8': '17351180'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 40,
#    'InstituicaoFinanceira': 'BCO C6 S.A.',
#    'TaxaJurosAoMes': 4.21,
#    'TaxaJurosAoAno': 64.02,
#    'cnpj8': '31872495'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 41,
#    'InstituicaoFinanceira': 'BRB - BCO DE BRASILIA S.A.',
#    'TaxaJurosAoMes': 4.5,
#    'TaxaJurosAoAno': 69.64,
#    'cnpj8': '00000208'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 42,
#    'InstituicaoFinanceira': 'CORA SCFI',
#    'TaxaJurosAoMes': 4.77,
#    'TaxaJurosAoAno': 74.95,
#    'cnpj8': '37880206'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 43,
#    'InstituicaoFinanceira': 'BANCO BTG PACTUAL S.A.',
#    'TaxaJurosAoMes': 4.99,
#    'TaxaJurosAoAno': 79.35,
#    'cnpj8': '30306294'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 44,
#    'InstituicaoFinanceira': 'BCO RNX S.A.',
#    'TaxaJurosAoMes': 5.12,
#    'TaxaJurosAoAno': 82.05,
#    'cnpj8': '80271455'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 45,
#    'InstituicaoFinanceira': 'NU FINANCEIRA S.A. CFI',
#    'TaxaJurosAoMes': 6.31,
#    'TaxaJurosAoAno': 108.49,
#    'cnpj8': '30680829'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 46,
#    'InstituicaoFinanceira': 'COBUCCIO S.A. SCFI',
#    'TaxaJurosAoMes': 8.67,
#    'TaxaJurosAoAno': 171.2,
#    'cnpj8': '36947229'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pré-fixado',
#    'Posicao': 47,
#    'InstituicaoFinanceira': 'MERCADO CRÉDITO SCFI S.A.',
#    'TaxaJurosAoMes': 9.13,
#    'TaxaJurosAoAno': 185.26,
#    'cnpj8': '37679449'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pós-fixado referenciado em juros flutuantes',
#    'Posicao': 1,
#    'InstituicaoFinanceira': 'BCO SAFRA S.A.',
#    'TaxaJurosAoMes': 0.44,
#    'TaxaJurosAoAno': 5.45,
#    'cnpj8': '58160789'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pós-fixado referenciado em juros flutuantes',
#    'Posicao': 2,
#    'InstituicaoFinanceira': 'DEUTSCHE BANK S.A.BCO ALEMAO',
#    'TaxaJurosAoMes': 0.83,
#    'TaxaJurosAoAno': 10.43,
#    'cnpj8': '62331228'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pós-fixado referenciado em juros flutuantes',
#    'Posicao': 3,
#    'InstituicaoFinanceira': 'BCO BOCOM BBM S.A.',
#    'TaxaJurosAoMes': 0.86,
#    'TaxaJurosAoAno': 10.79,
#    'cnpj8': '15114366'},
#   {'InicioPeriodo': '2024-09-19',
#    'FimPeriodo': '2024-09-25',
#    'codigoSegmento': None,
#    'Segmento': 'PESSOA JURÍDICA',
#    'codigoModalidade': None,
#    'Modalidade': 'Capital de giro com prazo até 365 dias - Pós-fixado referenciado em juros flutuantes',
#    'Posicao': 4,
#    'InstituicaoFinanceira': 'STONE CFI S.A.',
#    'TaxaJurosAoMes': 0.9,
#    'TaxaJurosAoAno': 11.4,
#    'cnpj8': '53505601'},
#   ...]}

# %%
# Criando o DataFrame no Pandas
df = pd.DataFrame(dados['value'])
df
# Out:
#       InicioPeriodo  FimPeriodo codigoSegmento         Segmento  \
# 0        2024-09-20  2024-09-26           None  PESSOA JURÍDICA
# 1        2024-09-20  2024-09-26           None  PESSOA JURÍDICA
# 2        2024-09-20  2024-09-26           None  PESSOA JURÍDICA
# 3        2024-09-20  2024-09-26           None  PESSOA JURÍDICA
# 4        2024-09-20  2024-09-26           None  PESSOA JURÍDICA
# ...             ...         ...            ...              ...
# 12231    2024-09-02  2024-09-06           None  PESSOA JURÍDICA
# 12232    2024-09-02  2024-09-06           None  PESSOA JURÍDICA
# 12233    2024-09-02  2024-09-06           None  PESSOA JURÍDICA
# 12234    2024-09-02  2024-09-06           None  PESSOA JURÍDICA
# 12235    2024-09-02  2024-09-06           None  PESSOA JURÍDICA
#
#       codigoModalidade                                         Modalidade  \
# 0                 None  Adiantamento sobre contratos de câmbio (ACC) -...
# 1                 None  Adiantamento sobre contratos de câmbio (ACC) -...
# 2                 None  Adiantamento sobre contratos de câmbio (ACC) -...
# 3                 None  Adiantamento sobre contratos de câmbio (ACC) -...
# 4                 None  Adiantamento sobre contratos de câmbio (ACC) -...
# ...                ...                                                ...
# 12231             None                                Vendor - Pré-fixado
# 12232             None                                Vendor - Pré-fixado
# 12233             None                                Vendor - Pré-fixado
# 12234             None                                Vendor - Pré-fixado
# 12235             None                                Vendor - Pré-fixado
#
#        Posicao          InstituicaoFinanceira  TaxaJurosAoMes  TaxaJurosAoAno  \
# 0            1                BCO MIZUHO S.A.            0.08            0.97
# 1            2    BCO SOCIETE GENERALE BRASIL            0.08            1.00
# 2            3    BCO CRÉDIT AGRICOLE BR S.A.            0.35            4.22
# 3            4  BCO RABOBANK INTL BRASIL S.A.            0.45            5.54
# 4            5             BCO DO BRASIL S.A.            0.47            5.76
# ...        ...                            ...             ...             ...
# 12231        4             BCO DO BRASIL S.A.            1.18           15.16
# 12232        5              BCO BRADESCO S.A.            1.44           18.76
# 12233        6             ITAÚ UNIBANCO S.A.            1.54           20.19
# 12234        7                SCANIA BCO S.A.            1.66           21.84
# 12235        8                OMNI BANCO S.A.            5.48           89.66
#
#           cnpj8
# 0      61088183
# 1      61533584
# 2      75647891
# 3      01023570
# 4      00000000
# ...         ...
# 12231  00000000
# 12232  60746948
# 12233  60701190
# 12234  11417016
# 12235  60850229
#
# [12236 rows x 11 columns]
