# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
#
# # EXTRAÇÃO DE DADOS VIA API
#
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ![api.png](api.png)

# %% [markdown]
# ### TAXA DE FINANCIAMENTO AUTOMOTIVO
#
# <br>
#
# Uma financeira está observando a oportunidade de entrar no mercado de financiamento automotivo.
#
#
# Para entrar de forma competitiva nesse mercado, a empresa sabe que precisa **tomar decisões baseadas em dados**, e após uma reunião estratégica foi levantado o desafio para o time de Data Science conseguir indicar uma taxa de juros de operações de crédito para aquisição de veículos que possa fazer frente aos melhores players do mercado!
#
# Desafios:
# <br>
# <br>
#
# **1. Como ter informações das taxas aplicadas pelo mercado?**
#
# **2. Como recuperar esses dados?**
#
#
#
#
#
#
#
#
#
#
#
#
# --------------------------------------------------------------------------------------------------------
# <br>
#
# <br>

# %% [markdown]
# ### 1. COMO TER INFORMAÇÕES DAS TAXAS APLICADAS PELO MERCADO?

# %% [markdown]
# O Banco Central do Brasil disponibiliza através de uma API gratuita informações sobre taxa de juros para diversas modalidades de crédito.
#
# https://dadosabertos.bcb.gov.br/dataset/taxas-de-juros-de-operacoes-de-credito/resource/cb682eb9-e9a9-497f-a1c4-299b385d09b9

# %% [markdown]
# ### 2. COMO RECUPERAR ESSES DADOS?
#
# Vamos utilizar a linguagem de programação Python para recuperar os dados
#
#
# API <- **PYTHON** -> COLETA -> TRATAMENTO -> DISPONIBILIZAÇÃO

# %%
import requests
import pandas as pd 
import json


url = 'https://olinda.bcb.gov.br/olinda/servico/taxaJuros/versao/v2/odata/TaxasJurosMensalPorMes?$format=json'

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
data = response.json()['value']

# %%
df = pd.DataFrame(data)
df
# Out:
#            Mes                                         Modalidade  Posicao  \
# 0     Set-2024  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...        1
# 1     Set-2024  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...        2
# 2     Set-2024  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...        3
# 3     Set-2024  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...        1
# 4     Set-2024  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...        2
# ...        ...                                                ...      ...
# 5043  Jan-2012  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...        8
# 5044  Jan-2012  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...        9
# 5045  Jan-2012  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...       10
# 5046  Jan-2012  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...       11
# 5047  Jan-2012  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...       12
#
#              InstituicaoFinanceira  TaxaJurosAoMes  TaxaJurosAoAno     cnpj8  \
# 0          CAIXA ECONOMICA FEDERAL            0.87           10.89  00360305
# 1      BCO SANTANDER (BRASIL) S.A.            1.10           13.98  90400888
# 2                       APE POUPEX            1.50           19.58  00655522
# 3                BCO BANESTES S.A.            0.75            9.33  28127603
# 4                       APE POUPEX            0.76            9.46  00655522
# ...                            ...             ...             ...       ...
# 5043             BCO BRADESCO S.A.            0.77            9.65  60746948
# 5044  BCO MERCANTIL DO BRASIL S.A.            0.80           10.03  17184037
# 5045                   KIRTON BANK            0.85           10.72  01701201
# 5046            ITAÚ UNIBANCO S.A.            0.91           11.52  60701190
# 5047                    APE POUPEX            1.18           15.08  00655522
#
#        anoMes
# 0     2024-09
# 1     2024-09
# 2     2024-09
# 3     2024-09
# 4     2024-09
# ...       ...
# 5043  2012-01
# 5044  2012-01
# 5045  2012-01
# 5046  2012-01
# 5047  2012-01
#
# [5048 rows x 8 columns]
