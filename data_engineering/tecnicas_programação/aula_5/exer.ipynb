# %%
import pandas as pd 

arquivo = pd.read_csv('penguins.csv')

arquivo
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
# df.groupby('classe_faltas')['Notas'].mean().reset_index()
df = pd.DataFrame(arquivo)
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
# df.groupby('classe_faltas')['Notas'].mean().reset_index()

df['sex'].value_counts(normalize=True).mul(100).astype(str) + '%'
# Out:
# sex
# MALE       50.45045045045045%
# FEMALE    49.549549549549546%
# Name: proportion, dtype: object

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
# dados faltante
print(df.isnull().sum())
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df_forbes = pd.read_csv('Forbes_Richest_Atheletes_1990_2020.csv')
df_forbes
# Out:
#      S.NO               Name Nationality  Current Rank Previous Year Rank  \
# 0       1         Mike Tyson         USA             1                NaN
# 1       2     Buster Douglas         USA             2                NaN
# 2       3  Sugar Ray Leonard         USA             3                NaN
# 3       4       Ayrton Senna      Brazil             4                NaN
# 4       5        Alain Prost      France             5                NaN
# ..    ...                ...         ...           ...                ...
# 296   297      Stephen Curry         USA             6                  9
# 297   298       Kevin Durant         USA             7                 10
# 298   299        Tiger Woods         USA             8                 11
# 299   300       Kirk Cousins         USA             9               >100
# 300   301       Carson Wentz         USA            10               >100
#
#                  Sport  Year  earnings ($ million)
# ...

# %%
df_forbes.head(10)
# Out:
#    S.NO               Name Nationality  Current Rank Previous Year Rank  \
# 0     1         Mike Tyson         USA             1                NaN
# 1     2     Buster Douglas         USA             2                NaN
# 2     3  Sugar Ray Leonard         USA             3                NaN
# 3     4       Ayrton Senna      Brazil             4                NaN
# 4     5        Alain Prost      France             5                NaN
# 5     6      Jack Nicklaus         USA             6                NaN
# 6     7        Greg Norman   Australia             7                NaN
# 7     8     Michael Jordan         USA             8                NaN
# 8     9      Arnold Palmer         USA             8                NaN
# 9    10  Evander Holyfield         USA             8                NaN
#
#          Sport  Year  earnings ($ million)
# 0       boxing  1990                  28.6
# 1       boxing  1990                  26.0
# 2       boxing  1990                  13.0
# ...

# %%
df_forbes['earnings ($ million)'].describe()
# Out:
# count    301.000000
# mean      45.516279
# std       33.525337
# min        8.100000
# 25%       24.000000
# 50%       39.000000
# 75%       59.400000
# max      300.000000
# Name: earnings ($ million), dtype: float64

# %%
df_forbes[df_forbes['Nationality']=='Brazil']
# Out:
#      S.NO          Name Nationality  Current Rank Previous Year Rank  \
# 3       4  Ayrton Senna      Brazil             4                NaN
# 14     15  Ayrton Senna      Brazil             5                  4
# 22     23  Ayrton Senna      Brazil             3                  5
# 32     33  Ayrton Senna      Brazil             3                  3
# 169   170    Ronaldinho      Brazil             9                >10
# 178   179    Ronaldinho      Brazil             8                  9
# 275   276        Neymar      Brazil             5                 18
# 283   284        Neymar      Brazil             3                  5
# 294   295        Neymar      Brazil             4                  3
#
#            Sport  Year  earnings ($ million)
# 3    auto racing  1990                  10.0
# 14   auto racing  1991                  13.0
# 22   Auto Racing  1992                  22.0
# 32   Auto racing  1993                  18.5
# 169       soccer  2007                  31.0
# ...

# %%
df_forbes[df_forbes['Nationality']=='USA']
# Out:
#      S.NO               Name Nationality  Current Rank Previous Year Rank  \
# 0       1         Mike Tyson         USA             1                NaN
# 1       2     Buster Douglas         USA             2                NaN
# 2       3  Sugar Ray Leonard         USA             3                NaN
# 5       6      Jack Nicklaus         USA             6                NaN
# 7       8     Michael Jordan         USA             8                NaN
# ..    ...                ...         ...           ...                ...
# 296   297      Stephen Curry         USA             6                  9
# 297   298       Kevin Durant         USA             7                 10
# 298   299        Tiger Woods         USA             8                 11
# 299   300       Kirk Cousins         USA             9               >100
# 300   301       Carson Wentz         USA            10               >100
#
#                  Sport  Year  earnings ($ million)
# ...

# %%
#df_costumers.rename(columns={"UUID": "Id"}, inplace=True)
df_forbes.rename(columns={'Name': 'Nome', 'Sport': 'Esporte', 'Year':'Ano', 'earnings ($ million)':'Ganhos em Milhões'}, inplace=True)

# %%
df_forbes
# Out:
#      S.NO               Nome Nationality  Current Rank Previous Year Rank  \
# 0       1         Mike Tyson         USA             1                NaN
# 1       2     Buster Douglas         USA             2                NaN
# 2       3  Sugar Ray Leonard         USA             3                NaN
# 3       4       Ayrton Senna      Brazil             4                NaN
# 4       5        Alain Prost      France             5                NaN
# ..    ...                ...         ...           ...                ...
# 296   297      Stephen Curry         USA             6                  9
# 297   298       Kevin Durant         USA             7                 10
# 298   299        Tiger Woods         USA             8                 11
# 299   300       Kirk Cousins         USA             9               >100
# 300   301       Carson Wentz         USA            10               >100
#
#                Esporte   Ano  Ganhos em Milhões
# ...

# %%
df_forbes.rename(columns={'Nationality': 'Nacionalidade'}, inplace=True)
df_forbes.rename(columns={'Current Rank': 'Rank Atual'}, inplace=True)
df_forbes
# Out:
#      S.NO               Nome Nacionalidade  Rank Atual Previous Year Rank  \
# 0       1         Mike Tyson           USA           1                NaN
# 1       2     Buster Douglas           USA           2                NaN
# 2       3  Sugar Ray Leonard           USA           3                NaN
# 3       4       Ayrton Senna        Brazil           4                NaN
# 4       5        Alain Prost        France           5                NaN
# ..    ...                ...           ...         ...                ...
# 296   297      Stephen Curry           USA           6                  9
# 297   298       Kevin Durant           USA           7                 10
# 298   299        Tiger Woods           USA           8                 11
# 299   300       Kirk Cousins           USA           9               >100
# 300   301       Carson Wentz           USA          10               >100
#
#                Esporte   Ano  Ganhos em Milhões
# ...

# %%
df_forbes[df_forbes['Ano'] > 2000].sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_20347/1991104559.py in ?()
# ----> 1 df_forbes[df_forbes['Ano'] > 2000].sort()
#
# ~/Documents/GitHub/Ada-Coders-2024/.venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
#df.sort_values(by='ano')
df_forbes.sort_values(by='Ano', ascending=False).head(50)
# Out:
#      S.NO               Nome     Nacionalidade  Rank Atual Previous Year Rank  \
# 300   301       Carson Wentz               USA          10               >100
# 299   300       Kirk Cousins               USA           9               >100
# 298   299        Tiger Woods               USA           8                 11
# 297   298       Kevin Durant               USA           7                 10
# 296   297      Stephen Curry               USA           6                  9
# 295   296       LeBron James               USA           5                  8
# 294   295             Neymar            Brazil           4                  3
# 293   294       Lionel Messi         Argentina           3                  1
# 292   293  Cristiano Ronaldo          Portugal           2                  2
# 291   292      Roger Federer       Switzerland           1                  5
# 290   291       Kevin Durant               USA          10                 11
# ...

# %%
#Estudar esse dataset
df_forbes.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   S.NO                301 non-null    int64
#  1   Nome                301 non-null    object
#  2   Nacionalidade       301 non-null    object
#  3   Rank Atual          301 non-null    int64
#  4   Previous Year Rank  277 non-null    object
#  5   Esporte             301 non-null    object
#  6   Ano                 301 non-null    int64
#  7   Ganhos em Milhões   301 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 74.8 KB

# %%
df_forbes.dropna()
# Out:
#      S.NO               Nome Nacionalidade  Rank Atual Previous Year Rank  \
# 10     11  Evander Holyfield           USA           1                  8
# 11     12         Mike Tyson           USA           2                  1
# 12     13     Michael Jordan           USA           3                  8
# 13     14     George Foreman           USA           4                >30
# 14     15       Ayrton Senna        Brazil           5                  4
# ..    ...                ...           ...         ...                ...
# 296   297      Stephen Curry           USA           6                  9
# 297   298       Kevin Durant           USA           7                 10
# 298   299        Tiger Woods           USA           8                 11
# 299   300       Kirk Cousins           USA           9               >100
# 300   301       Carson Wentz           USA          10               >100
#
#                Esporte   Ano  Ganhos em Milhões
# ...

# %%
df_forbes['Ganhos em Milhões'].max()
# Out:
# np.float64(300.0)

# %%
df_forbes.groupby(['Nome','Ano'],as_index=False)['Ganhos em Milhões'].min().sort_values(by='Ganhos em Milhões', ascending=False)
# Out:
#                   Nome   Ano  Ganhos em Milhões
# 72    Floyd Mayweather  2015              300.0
# 73    Floyd Mayweather  2018              285.0
# 156     Manny Pacquiao  2015              160.0
# 151       Lionel Messi  2019              127.0
# 285        Tiger Woods  2008              115.0
# ..                 ...   ...                ...
# 85         Greg Norman  1990                8.5
# 271  Sugar Ray Leonard  1991                8.5
# 16       Arnold Palmer  1990                8.1
# 62   Evander Holyfield  1990                8.1
# 160     Michael Jordan  1990                8.1
#
# [301 rows x 3 columns]
