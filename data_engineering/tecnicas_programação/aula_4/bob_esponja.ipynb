# %%
import pandas as pd 

df = pd.read_csv('spongebob_episodes.csv')

df
# Out:
#               Airdate                                   Animation  \
# 0           1997/1998                                  Alan Smart
# 1         May 1, 1999  ['Fred Miller', 'Tom Yasumi (uncredited)']
# 2         May 1, 1999                                  Tom Yasumi
# 3       July 17, 1999                                  Tom Yasumi
# 4       July 17, 1999                            Edgar Larrazábal
# ..                ...                                         ...
# 578     July 22, 2024                                         NaN
# 579     July 23, 2024                             Andrew Overtoom
# 580     July 24, 2024                             Andrew Overtoom
# 581     July 25, 2024                              Michelle Bryan
# 582  October 29, 2024                                         NaN
#
#     Animation Supervisor                                  Copyright year  \
# 0                    NaN  ['1997 (1997 version)', '1999 (1999 version)']
# ...

# %%
colunas = df.columns.tolist()
len(df.columns.tolist())
colunas
# Out:
# ['Airdate',
#  'Animation',
#  'Animation Supervisor',
#  'Copyright year',
#  'Creative',
#  'Episode №',
#  'Guest(s)',
#  'Line Producer',
#  'Main',
#  'Next',
#  'Previous',
#  'Production code',
#  'Running time',
#  'Season №',
#  'Sister episode(s)',
#  'Storyboard',
#  'Storyboard Artist(s)',
#  'Supervising',
#  'Supervising Producer(s)',
#  'Technical',
#  'U.S. premiere time (ET)',
#  'U.S. viewers (millions)',
#  'Writer(s)',
#  'characters',
#  'title']

# %%
df['title']
# Out:
# 0                            Help Wanted
# 1                            Reef Blower
# 2                    Tea at the Treedome
# 3                            Bubblestand
# 4                           Ripped Pants
#                      ...
# 578                The Dirty Bubble Bass
# 579                  Sheldon SquarePants
# 580                     Sammy Suckerfish
# 581                       Big League Bob
# 582    Snow Yellow and the Seven Jellies
# Name: title, Length: 583, dtype: object

# %%
for numero, episodio in enumerate(df['title']):
    print(f'{numero + 1} - {episodio}')
# Out:
# 1 - Help Wanted
# 2 - Reef Blower
# 3 - Tea at the Treedome
# 4 - Bubblestand
# 5 - Ripped Pants
# 6 - Jellyfishing
# 7 - Plankton!
# 8 - Naughty Nautical Neighbors
# 9 - Boating School
# 10 - Pizza Delivery
# 11 - Home Sweet Pineapple
# 12 - Mermaid Man and Barnacle Boy
# 13 - Pickles
# 14 - Hall Monitor
# 15 - Jellyfish Jam
# 16 - Sandy's Rocket
# 17 - Squeaky Boots
# 18 - Nature Pants
# 19 - Opposite Day
# 20 - Culture Shock
# 21 - F.U.N.
# 22 - MuscleBob BuffPants
# 23 - Squidward the Unfriendly Ghost
# 24 - The Chaperone
# 25 - Employee of the Month
# 26 - Scaredy Pants
# 27 - I Was a Teenage Gary
# 28 - SB-129
# 29 - Karate Choppers
# 30 - Sleepy Time
# 31 - Suds
# 32 - Valentine's Day
# 33 - The Paper
# 34 - Arrgh!
# 35 - Rock Bottom
# 36 - Texas
# 37 - Walking Small
# 38 - Fools in April
# 39 - Neptune's Spatula
# 40 - Hooky
# 41 - Mermaid Man and Barnacle Boy II
# 42 - Your Shoe's Untied
# 43 - Squid's Day Off
# 44 - Something Smells
# 45 - Bossy Boots
# 46 - Big Pink Loser
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Airdate                  583 non-null    object
#  1   Animation                569 non-null    object
#  2   Animation Supervisor     2 non-null      object
#  3   Copyright year           583 non-null    object
#  4   Creative                 329 non-null    object
#  5   Episode №                583 non-null    object
#  6   Guest(s)                 190 non-null    object
#  7   Line Producer            68 non-null     object
#  8   Main                     21 non-null     object
#  9   Next                     583 non-null    object
#  10  Previous                 582 non-null    object
#  11  Production code          583 non-null    object
#  12  Running time             583 non-null    object
#  13  Season №                 583 non-null    int64
# ...

# %%
# Filtragem
df
# Out:
# "SpongeBob SquarePants, Jellyfish, Lavender jellyfish, Sandy Cheeks, Giant clam, Patrick Star, Sandy's orange bird"
