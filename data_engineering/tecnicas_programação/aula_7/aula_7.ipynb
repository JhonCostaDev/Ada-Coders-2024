# %%
import pandas as pd 

df = pd.read_csv('../aula_4/spongebob_episodes.csv')
df
# Out:
#               Airdate                                   Animation  \
# 0           1997/1998                                  Alan Smart
# 1         May 1, 1999  ['Fred Miller', 'Tom Yasumi (uncredited)']
# 2         May 1, 1999                                  Tom Yasumi
# 3       July 17, 1999                                  Tom Yasumi
# 4       July 17, 1999                            Edgar Larrazábal
# ..                ...                                         ...
# 578     July 22, 2024                                         NaN
# 579     July 23, 2024                             Andrew Overtoom
# 580     July 24, 2024                             Andrew Overtoom
# 581     July 25, 2024                              Michelle Bryan
# 582  October 29, 2024                                         NaN
#
#     Animation Supervisor                                  Copyright year  \
# 0                    NaN  ['1997 (1997 version)', '1999 (1999 version)']
# ...

# %%
# netflix

df_netflix = pd.read_csv('netflix_titles.csv')
df_netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#Penguins

df_penguins = pd.read_csv('../aula_5/penguins.csv')
df_penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df_penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
import numpy as np 
categoricos = df_penguins.select_dtypes(exclude=np.number)
categoricos
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    MALE
# 1    Adelie  Torgersen  FEMALE
# 2    Adelie  Torgersen  FEMALE
# 3    Adelie  Torgersen     NaN
# 4    Adelie  Torgersen  FEMALE
# ..      ...        ...     ...
# 339  Gentoo     Biscoe     NaN
# 340  Gentoo     Biscoe  FEMALE
# 341  Gentoo     Biscoe    MALE
# 342  Gentoo     Biscoe  FEMALE
# 343  Gentoo     Biscoe    MALE
#
# [344 rows x 3 columns]

# %%
for coluna in categoricos:
    print(f'Coluna = {coluna}')
    display(categoricos[coluna].value_counts(dropna = False).reset_index())
    #display(categoricos[coluna].value_counts(dropna = False).reset_index())
# Out:
# Coluna = species
#      species  count
# 0     Adelie    152
# 1     Gentoo    124
# 2  Chinstrap     68
# Coluna = island
#       island  count
# 0     Biscoe    168
# 1      Dream    124
# 2  Torgersen     52
# Coluna = sex
#       sex  count
# 0    MALE    168
# 1  FEMALE    165
# 2     NaN     11

# %%
df_num = df.select_dtypes(include=np.number)

# %%
for coluna in df_num.columns:
    print(f'\nColuna = {coluna}')
    display(df_num[coluna].describe().round(2).reset_index())
    print('')
# Out:
# Coluna = Season №
#    index  Season №
# 0  count    583.00
# 1   mean      7.49
# 2    std      3.90
# 3    min      1.00
# 4    25%      4.00
# 5    50%      7.00
# 6    75%     11.00
# 7    max     14.00

# %%
# ver se tem dados duplicados
df_penguins.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_penguins[['species', 'island']].duplicated()
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Length: 344, dtype: bool

# %%
df_species_island = df_penguins[['species', 'island']]

df_species_island[df_species_island.duplicated()]
# Out:
#     species     island
# 1    Adelie  Torgersen
# 2    Adelie  Torgersen
# 3    Adelie  Torgersen
# 4    Adelie  Torgersen
# 5    Adelie  Torgersen
# ..      ...        ...
# 339  Gentoo     Biscoe
# 340  Gentoo     Biscoe
# 341  Gentoo     Biscoe
# 342  Gentoo     Biscoe
# 343  Gentoo     Biscoe
#
# [339 rows x 2 columns]

# %% [markdown]
# Letícia Bertoldi
# 21:59
# pd.api.types.is_datetime64_any_dtype(self.df[coluna])
# Raul Felipe
# 22:00
# rapaz kkkk
# Nicolas Parisotto
# 22:00
# g zuz
# Letícia Bertoldi
# 22:00
# agrupa dados por ano
# self.df[coluna].groupby(self.df[coluna].dt.year).count()
